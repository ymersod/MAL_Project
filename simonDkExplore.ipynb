# %% [markdown]
# ### 3. Explore the data
# 1. Create a copy of the data for explorations (sampling it down to a manageable size if necessary)
# 2. Create a Jupyter notebook to keep a record of your data exploration
# 3. Study each feature and its characteristics:
#     * Name
#     * Type (categorical, int/float, bounded/unbounded, text, structured, etc)
#     * Percentage of missing values
#     * Check for outliers, rounding errors etc
# 4. For supervised learning tasks, identify the target(s)
# 5. Visualise the data
# 6. Study the correlations between features
# 7. Identify the promising transformations you may want to apply (e.g. convert skewed targets to normal via a log transformation)
# 8. Document what you have learned

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('AnimeList.csv')

df
# Out:
#        anime_id                                  title  \
# 0         11013                          Inu x Boku SS
# 1          2104                       Seto no Hanayome
# 2          5262                     Shugo Chara!! Doki
# 3           721                          Princess Tutu
# 4         12365                    Bakuman. 3rd Season
# ...         ...                                    ...
# 14473     26089             Gutchonpa Omoshiro Hanashi
# 14474     21525                   Geba Geba Shou Time!
# 14475     37897            Godzilla: Hoshi wo Kuu Mono
# 14476     34193  Nippon Mukashibanashi: Sannen Netarou
# 14477     37908             Senjou no Valkyria Special
#
#                    title_english                  title_japanese  \
# 0      Inu X Boku Secret Service                          妖狐×僕SS
# 1          My Bride is a Mermaid                           瀬戸の花嫁
# 2             Shugo Chara!! Doki                     しゅごキャラ！！どきっ
# 3                  Princess Tutu                       プリンセスチュチュ
# 4                       Bakuman.                           バクマン。
# ...                          ...                             ...
# 14473                        NaN                     グッチョンパおもしろ話
# 14474                        NaN                       ゲバゲバ笑タイム!
# 14475                        NaN                GODZILLA -星を喰う者-
# 14476                        NaN                   日本昔ばなし 三ねん寝太郎
# 14477                        NaN  戦場のヴァルキュリア Valkyria Chronicles
#
#                                       title_synonyms  \
# 0                                    Youko x Boku SS
# 1                               The Inland Sea Bride
# 2      Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                                NaN
# 4                                   Bakuman Season 3
# ...                                              ...
# 14473                                            NaN
# 14474                                            NaN
# 14475      Godzilla Part 3, Godzilla: Eater of Stars
# 14476                                            NaN
# 14477            Senjou no Valkyria Fake Movie Promo
#
#                                                image_url     type    source  \
# 0      https://myanimelist.cdn-dena.com/images/anime/...       TV     Manga
# 1      https://myanimelist.cdn-dena.com/images/anime/...       TV     Manga
# 2      https://myanimelist.cdn-dena.com/images/anime/...       TV     Manga
# 3      https://myanimelist.cdn-dena.com/images/anime/...       TV  Original
# 4      https://myanimelist.cdn-dena.com/images/anime/...       TV     Manga
# ...                                                  ...      ...       ...
# 14473  https://myanimelist.cdn-dena.com/images/anime/...       TV   Unknown
# 14474  https://myanimelist.cdn-dena.com/images/anime/...      OVA   Unknown
# 14475  https://myanimelist.cdn-dena.com/images/anime/...    Movie     Other
# 14476  https://myanimelist.cdn-dena.com/images/anime/...      OVA     Other
# 14477  https://myanimelist.cdn-dena.com/images/anime/...  Special   Unknown
#
#        episodes           status  ...  \
# 0            12  Finished Airing  ...
# 1            26  Finished Airing  ...
# 2            51  Finished Airing  ...
# 3            38  Finished Airing  ...
# 4            25  Finished Airing  ...
# ...         ...              ...  ...
# 14473         5  Finished Airing  ...
# 14474         1  Finished Airing  ...
# 14475         1    Not yet aired  ...
# 14476         1  Finished Airing  ...
# 14477         1  Finished Airing  ...
#
#                                               background    premiered  \
# 0      Inu x Boku SS was licensed by Sentai Filmworks...  Winter 2012
# 1                                                    NaN  Spring 2007
# 2                                                    NaN    Fall 2008
# 3      Princess Tutu aired in two parts. The first pa...  Summer 2002
# 4                                                    NaN    Fall 2012
# ...                                                  ...          ...
# 14473                                                NaN    Fall 1987
# 14474                                                NaN          NaN
# 14475                                                NaN          NaN
# 14476                                                NaN          NaN
# 14477                                                NaN          NaN
#
#                 broadcast                                            related  \
# 0      Fridays at Unknown  {'Adaptation': [{'mal_id': 17207, 'type': 'man...
# 1                 Unknown  {'Adaptation': [{'mal_id': 759, 'type': 'manga...
# 2                 Unknown  {'Adaptation': [{'mal_id': 101, 'type': 'manga...
# 3      Fridays at Unknown  {'Adaptation': [{'mal_id': 1581, 'type': 'mang...
# 4                 Unknown  {'Adaptation': [{'mal_id': 9711, 'type': 'mang...
# ...                   ...                                                ...
# 14473             Unknown  {'Other': [{'mal_id': 26087, 'type': 'anime', ...
# 14474                 NaN                                                 []
# 14475                 NaN  {'Prequel': [{'mal_id': 36816, 'type': 'anime'...
# 14476                 NaN                                                 []
# 14477                 NaN  {'Other': [{'mal_id': 5507, 'type': 'anime', '...
#
#                                                 producer          licensor  \
# 0      Aniplex, Square Enix, Mainichi Broadcasting Sy...  Sentai Filmworks
# 1                      TV Tokyo, AIC, Square Enix, Sotsu        Funimation
# 2                                        TV Tokyo, Sotsu               NaN
# 3                     Memory-Tech, GANSIS, Marvelous AQL         ADV Films
# 4                                          NHK, Shueisha               NaN
# ...                                                  ...               ...
# 14473                                                NaN               NaN
# 14474                                       Studio Lotus               NaN
# 14475                                                NaN               NaN
# 14476                                                NaN               NaN
# 14477                                                NaN               NaN
#
#                  studio                                     genre  \
# 0      David Production    Comedy, Supernatural, Romance, Shounen
# 1                 Gonzo  Comedy, Parody, Romance, School, Shounen
# 2             Satelight             Comedy, Magic, School, Shoujo
# 3        Hal Film Maker    Comedy, Drama, Magic, Romance, Fantasy
# 4             J.C.Staff           Comedy, Drama, Romance, Shounen
# ...                 ...                                       ...
# 14473               NaN                                      Kids
# 14474               NaN                                    Comedy
# 14475               NaN        Action, Sci-Fi, Adventure, Fantasy
# 14476               NaN                             Fantasy, Kids
# 14477      A-1 Pictures                                    Comedy
#
#                                            opening_theme  \
# 0                                  ['"Nirvana" by MUCC']
# 1                     ['"Romantic summer" by SUN&LUNAR']
# 2      ['#1: "Minna no Tamago (みんなのたまご)" by Shugo Cha...
# 3                 ['"Morning Grace" by Ritsuko Okazaki']
# 4      ['#1: "Moshimo no Hanashi (もしもの話)" by nano.RIP...
# ...                                                  ...
# 14473                                                 []
# 14474                                                 []
# 14475                                                 []
# 14476                                                 []
# 14477                                                 []
#
#                                             ending_theme
# 0      ['#1: "Nirvana" by MUCC (eps 1, 11-12)', '#2: ...
# 1      ['#1: "Ashita e no Hikari (明日への光)" by Asuka Hi...
# 2      ['#1: "Rottara Rottara (ロッタラ ロッタラ)" by Buono! ...
# 3      ['"Watashi No Ai Wa Chiisaikeredo" by Ritsuko ...
# 4      ['#1: "Pride on Everyday" by Sphere (eps 1-13)...
# ...                                                  ...
# 14473                                                 []
# 14474                                                 []
# 14475                                                 []
# 14476                                                 []
# 14477                                                 []
#
# [14478 rows x 31 columns]

# %% [markdown]
# # Study data
#
# ## Start by removing columns with useless information as to predict ranking

# %%
# Start by cutting out useless columns

# id non saying info
# image_url no
# status, airing, aired_string, aired - we predict on upcoming anime
# 'favorites', 'popularity', 'rank', 'scored_by'- these are all metrics that are put on after being ranked
# Members ????

df_copy = df.copy()

column_names = df_copy.columns
print(column_names)

cols_to_drop = ['anime_id', 'image_url', 'status', 'airing', 'aired_string', 'aired', 'favorites', 'popularity', 'rank', 'scored_by', 'members']
df_copy = df_copy.drop(columns=cols_to_drop)
column_names = df_copy.columns
print(column_names)

df_copy
# Out:
# Index(['anime_id', 'title', 'title_english', 'title_japanese',
#        'title_synonyms', 'image_url', 'type', 'source', 'episodes', 'status',
#        'airing', 'aired_string', 'aired', 'duration', 'rating', 'score',
#        'scored_by', 'rank', 'popularity', 'members', 'favorites', 'background',
#        'premiered', 'broadcast', 'related', 'producer', 'licensor', 'studio',
#        'genre', 'opening_theme', 'ending_theme'],
#       dtype='object')
# Index(['title', 'title_english', 'title_japanese', 'title_synonyms', 'type',
#        'source', 'episodes', 'duration', 'rating', 'score', 'background',
#        'premiered', 'broadcast', 'related', 'producer', 'licensor', 'studio',
#        'genre', 'opening_theme', 'ending_theme'],
#       dtype='object')
#                                        title              title_english  \
# 0                              Inu x Boku SS  Inu X Boku Secret Service
# 1                           Seto no Hanayome      My Bride is a Mermaid
# 2                         Shugo Chara!! Doki         Shugo Chara!! Doki
# 3                              Princess Tutu              Princess Tutu
# 4                        Bakuman. 3rd Season                   Bakuman.
# ...                                      ...                        ...
# 14473             Gutchonpa Omoshiro Hanashi                        NaN
# 14474                   Geba Geba Shou Time!                        NaN
# 14475            Godzilla: Hoshi wo Kuu Mono                        NaN
# 14476  Nippon Mukashibanashi: Sannen Netarou                        NaN
# 14477             Senjou no Valkyria Special                        NaN
#
#                        title_japanese  \
# 0                              妖狐×僕SS
# 1                               瀬戸の花嫁
# 2                         しゅごキャラ！！どきっ
# 3                           プリンセスチュチュ
# 4                               バクマン。
# ...                               ...
# 14473                     グッチョンパおもしろ話
# 14474                       ゲバゲバ笑タイム!
# 14475                GODZILLA -星を喰う者-
# 14476                   日本昔ばなし 三ねん寝太郎
# 14477  戦場のヴァルキュリア Valkyria Chronicles
#
#                                       title_synonyms     type    source  \
# 0                                    Youko x Boku SS       TV     Manga
# 1                               The Inland Sea Bride       TV     Manga
# 2      Shugo Chara Ninenme, Shugo Chara! Second Year       TV     Manga
# 3                                                NaN       TV  Original
# 4                                   Bakuman Season 3       TV     Manga
# ...                                              ...      ...       ...
# 14473                                            NaN       TV   Unknown
# 14474                                            NaN      OVA   Unknown
# 14475      Godzilla Part 3, Godzilla: Eater of Stars    Movie     Other
# 14476                                            NaN      OVA     Other
# 14477            Senjou no Valkyria Fake Movie Promo  Special   Unknown
#
#        episodes         duration                          rating  score  \
# 0            12  24 min. per ep.       PG-13 - Teens 13 or older   7.63
# 1            26  24 min. per ep.       PG-13 - Teens 13 or older   7.89
# 2            51  24 min. per ep.                   PG - Children   7.55
# 3            38  16 min. per ep.       PG-13 - Teens 13 or older   8.21
# 4            25  24 min. per ep.       PG-13 - Teens 13 or older   8.67
# ...         ...              ...                             ...    ...
# 14473         5   8 min. per ep.                    G - All Ages   5.50
# 14474         1          25 min.                    G - All Ages   4.60
# 14475         1          Unknown  R - 17+ (violence & profanity)   0.00
# 14476         1          40 min.                    G - All Ages   6.00
# 14477         1           3 min.       PG-13 - Teens 13 or older   5.15
#
#                                               background    premiered  \
# 0      Inu x Boku SS was licensed by Sentai Filmworks...  Winter 2012
# 1                                                    NaN  Spring 2007
# 2                                                    NaN    Fall 2008
# 3      Princess Tutu aired in two parts. The first pa...  Summer 2002
# 4                                                    NaN    Fall 2012
# ...                                                  ...          ...
# 14473                                                NaN    Fall 1987
# 14474                                                NaN          NaN
# 14475                                                NaN          NaN
# 14476                                                NaN          NaN
# 14477                                                NaN          NaN
#
#                 broadcast                                            related  \
# 0      Fridays at Unknown  {'Adaptation': [{'mal_id': 17207, 'type': 'man...
# 1                 Unknown  {'Adaptation': [{'mal_id': 759, 'type': 'manga...
# 2                 Unknown  {'Adaptation': [{'mal_id': 101, 'type': 'manga...
# 3      Fridays at Unknown  {'Adaptation': [{'mal_id': 1581, 'type': 'mang...
# 4                 Unknown  {'Adaptation': [{'mal_id': 9711, 'type': 'mang...
# ...                   ...                                                ...
# 14473             Unknown  {'Other': [{'mal_id': 26087, 'type': 'anime', ...
# 14474                 NaN                                                 []
# 14475                 NaN  {'Prequel': [{'mal_id': 36816, 'type': 'anime'...
# 14476                 NaN                                                 []
# 14477                 NaN  {'Other': [{'mal_id': 5507, 'type': 'anime', '...
#
#                                                 producer          licensor  \
# 0      Aniplex, Square Enix, Mainichi Broadcasting Sy...  Sentai Filmworks
# 1                      TV Tokyo, AIC, Square Enix, Sotsu        Funimation
# 2                                        TV Tokyo, Sotsu               NaN
# 3                     Memory-Tech, GANSIS, Marvelous AQL         ADV Films
# 4                                          NHK, Shueisha               NaN
# ...                                                  ...               ...
# 14473                                                NaN               NaN
# 14474                                       Studio Lotus               NaN
# 14475                                                NaN               NaN
# 14476                                                NaN               NaN
# 14477                                                NaN               NaN
#
#                  studio                                     genre  \
# 0      David Production    Comedy, Supernatural, Romance, Shounen
# 1                 Gonzo  Comedy, Parody, Romance, School, Shounen
# 2             Satelight             Comedy, Magic, School, Shoujo
# 3        Hal Film Maker    Comedy, Drama, Magic, Romance, Fantasy
# 4             J.C.Staff           Comedy, Drama, Romance, Shounen
# ...                 ...                                       ...
# 14473               NaN                                      Kids
# 14474               NaN                                    Comedy
# 14475               NaN        Action, Sci-Fi, Adventure, Fantasy
# 14476               NaN                             Fantasy, Kids
# 14477      A-1 Pictures                                    Comedy
#
#                                            opening_theme  \
# 0                                  ['"Nirvana" by MUCC']
# 1                     ['"Romantic summer" by SUN&LUNAR']
# 2      ['#1: "Minna no Tamago (みんなのたまご)" by Shugo Cha...
# 3                 ['"Morning Grace" by Ritsuko Okazaki']
# 4      ['#1: "Moshimo no Hanashi (もしもの話)" by nano.RIP...
# ...                                                  ...
# 14473                                                 []
# 14474                                                 []
# 14475                                                 []
# 14476                                                 []
# 14477                                                 []
#
#                                             ending_theme
# 0      ['#1: "Nirvana" by MUCC (eps 1, 11-12)', '#2: ...
# 1      ['#1: "Ashita e no Hikari (明日への光)" by Asuka Hi...
# 2      ['#1: "Rottara Rottara (ロッタラ ロッタラ)" by Buono! ...
# 3      ['"Watashi No Ai Wa Chiisaikeredo" by Ritsuko ...
# 4      ['#1: "Pride on Everyday" by Sphere (eps 1-13)...
# ...                                                  ...
# 14473                                                 []
# 14474                                                 []
# 14475                                                 []
# 14476                                                 []
# 14477                                                 []
#
# [14478 rows x 20 columns]

# %% [markdown]
# ## Study amount of NaN's

# %%
nan_counts = df_copy.isna().sum()
nan_counts
# Out:
# title                 0
# title_english      8754
# title_japanese       35
# title_synonyms     5541
# type                  0
# source                0
# episodes              0
# aired                 0
# duration              0
# rating              544
# score                 0
# background        13421
# premiered         10382
# broadcast         10207
# related               0
# producer           6190
# licensor          11105
# studio             5934
# genre                64
# opening_theme         0
# ending_theme          0
# dtype: int64

# %% [markdown]
# ## Lets look more closely at the 8 features with alot of NaNs

# %%
values_to_keep = ['title_english', 'title_synonyms', 'background', 'premiered', 'broadcast', 'producer', 'licensor', 'studio']

nan_df = df_copy[df_copy.columns.intersection(values_to_keep)]
nan_df
# Out:
#                    title_english  \
# 0      Inu X Boku Secret Service
# 1          My Bride is a Mermaid
# 2             Shugo Chara!! Doki
# 3                  Princess Tutu
# 4                       Bakuman.
# ...                          ...
# 14473                        NaN
# 14474                        NaN
# 14475                        NaN
# 14476                        NaN
# 14477                        NaN
#
#                                       title_synonyms  \
# 0                                    Youko x Boku SS
# 1                               The Inland Sea Bride
# 2      Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                                NaN
# 4                                   Bakuman Season 3
# ...                                              ...
# 14473                                            NaN
# 14474                                            NaN
# 14475      Godzilla Part 3, Godzilla: Eater of Stars
# 14476                                            NaN
# 14477            Senjou no Valkyria Fake Movie Promo
#
#                                               background    premiered  \
# 0      Inu x Boku SS was licensed by Sentai Filmworks...  Winter 2012
# 1                                                    NaN  Spring 2007
# 2                                                    NaN    Fall 2008
# 3      Princess Tutu aired in two parts. The first pa...  Summer 2002
# 4                                                    NaN    Fall 2012
# ...                                                  ...          ...
# 14473                                                NaN    Fall 1987
# 14474                                                NaN          NaN
# 14475                                                NaN          NaN
# 14476                                                NaN          NaN
# 14477                                                NaN          NaN
#
#                 broadcast                                           producer  \
# 0      Fridays at Unknown  Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 1                 Unknown                  TV Tokyo, AIC, Square Enix, Sotsu
# 2                 Unknown                                    TV Tokyo, Sotsu
# 3      Fridays at Unknown                 Memory-Tech, GANSIS, Marvelous AQL
# 4                 Unknown                                      NHK, Shueisha
# ...                   ...                                                ...
# 14473             Unknown                                                NaN
# 14474                 NaN                                       Studio Lotus
# 14475                 NaN                                                NaN
# 14476                 NaN                                                NaN
# 14477                 NaN                                                NaN
#
#                licensor            studio
# 0      Sentai Filmworks  David Production
# 1            Funimation             Gonzo
# 2                   NaN         Satelight
# 3             ADV Films    Hal Film Maker
# 4                   NaN         J.C.Staff
# ...                 ...               ...
# 14473               NaN               NaN
# 14474               NaN               NaN
# 14475               NaN               NaN
# 14476               NaN               NaN
# 14477               NaN      A-1 Pictures
#
# [14478 rows x 8 columns]

# %% [markdown]
# We can prob just remove these 2 title things as we already have title + title_japanese
#
# Background has over 90% NaN and it doesn't look interesting
#
# Premiered has alot of nans, maybe aired is better.
#
# Broadcast looked fun but over 2/3 is NaN
#
# Lets look at how many different producers/liscensors/studios there are to see if they can be used

# %%
print(nan_df['producer'].value_counts())
print(nan_df['licensor'].value_counts())
print(nan_df['studio'].value_counts())
# Out:
# producer
# NHK                                                            427
# Sanrio                                                         157
# Pink Pineapple                                                 155
# Bandai Visual                                                  117
# Fuji TV                                                        102
#                                                               ...
# Dentsu, Starchild Records, Imagica, Rakuonsha, King Records      1
# Sotsu, Lantis, Warner Bros., Shogakukan                          1
# Imagica, Mippei Eigeki Kiryuukan                                 1
# Yomiko Advertising, Shueisha                                     1
# Studio Lotus                                                     1
# Name: count, Length: 3221, dtype: int64

# %%
print(nan_df['licensor'].value_counts())
# Out:
# licensor
# Funimation                                                726
# Sentai Filmworks                                          572
# Media Blasters                                            208
# ADV Films                                                 157
# Viz Media                                                 134
#                                                          ...
# Bandai Entertainment, Maiden Japan                          1
# Viz Media, Flatiron Film Company                            1
# Haoliners Animation League                                  1
# ADV Films, Funimation, Kadokawa Pictures USA                1
# Funimation, Sentai Filmworks, Geneon Entertainment USA      1
# Name: count, Length: 193, dtype: int64

# %%
print(nan_df['studio'].value_counts())
# Out:
# studio
# Toei Animation                         725
# Sunrise                                447
# J.C.Staff                              314
# Madhouse                               311
# Production I.G                         251
#                                       ...
# Toei Animation, Bridge                   1
# CUCURI, Digital Network Animation        1
# Studio Unicorn                           1
# Bee Train, Cookie Jar Entertainment      1
# 33 Collective                            1
# Name: count, Length: 778, dtype: int64

# %% [markdown]
# Theres some big studios and a ton of small independent producers - maybe we can use the 10 top most studios, and set the rest below some threshhold to unknown, as to not give bias with low amounts of data (outliers we have to take care of)

# %% [markdown]
# ### Cleaning up

# %%
df_copy = df.copy()

# keep aired instead of premiered
cols_to_drop = ['anime_id', 'image_url', 'status', 'airing', 'aired_string', 'broadcast',
                 'premiered', 'favorites', 'popularity', 'rank', 'scored_by', 'members', 'title_english', 'title_synonyms', 'background']

df_copy = df_copy.drop(columns=cols_to_drop)
column_names = df_copy.columns
print(column_names)

print(df_copy.isna().sum())
df_copy
# Out:
# Index(['title', 'title_japanese', 'type', 'source', 'episodes', 'aired',
#        'duration', 'rating', 'score', 'related', 'producer', 'licensor',
#        'studio', 'genre', 'opening_theme', 'ending_theme'],
#       dtype='object')
# title                 0
# title_japanese       35
# type                  0
# source                0
# episodes              0
# aired                 0
# duration              0
# rating              544
# score                 0
# related               0
# producer           6190
# licensor          11105
# studio             5934
# genre                64
# opening_theme         0
# ending_theme          0
# dtype: int64
#                                        title                  title_japanese  \
# 0                              Inu x Boku SS                          妖狐×僕SS
# 1                           Seto no Hanayome                           瀬戸の花嫁
# 2                         Shugo Chara!! Doki                     しゅごキャラ！！どきっ
# 3                              Princess Tutu                       プリンセスチュチュ
# 4                        Bakuman. 3rd Season                           バクマン。
# ...                                      ...                             ...
# 14473             Gutchonpa Omoshiro Hanashi                     グッチョンパおもしろ話
# 14474                   Geba Geba Shou Time!                       ゲバゲバ笑タイム!
# 14475            Godzilla: Hoshi wo Kuu Mono                GODZILLA -星を喰う者-
# 14476  Nippon Mukashibanashi: Sannen Netarou                   日本昔ばなし 三ねん寝太郎
# 14477             Senjou no Valkyria Special  戦場のヴァルキュリア Valkyria Chronicles
#
#           type    source  episodes  \
# 0           TV     Manga        12
# 1           TV     Manga        26
# 2           TV     Manga        51
# 3           TV  Original        38
# 4           TV     Manga        25
# ...        ...       ...       ...
# 14473       TV   Unknown         5
# 14474      OVA   Unknown         1
# 14475    Movie     Other         1
# 14476      OVA     Other         1
# 14477  Special   Unknown         1
#
#                                             aired         duration  \
# 0      {'from': '2012-01-13', 'to': '2012-03-30'}  24 min. per ep.
# 1      {'from': '2007-04-02', 'to': '2007-10-01'}  24 min. per ep.
# 2      {'from': '2008-10-04', 'to': '2009-09-25'}  24 min. per ep.
# 3      {'from': '2002-08-16', 'to': '2003-05-23'}  16 min. per ep.
# 4      {'from': '2012-10-06', 'to': '2013-03-30'}  24 min. per ep.
# ...                                           ...              ...
# 14473  {'from': '1987-11-05', 'to': '1988-11-04'}   8 min. per ep.
# 14474  {'from': '1986-03-21', 'to': '1986-03-21'}          25 min.
# 14475                  {'from': None, 'to': None}          Unknown
# 14476                  {'from': None, 'to': None}          40 min.
# 14477  {'from': '2010-04-07', 'to': '2010-04-07'}           3 min.
#
#                                rating  score  \
# 0           PG-13 - Teens 13 or older   7.63
# 1           PG-13 - Teens 13 or older   7.89
# 2                       PG - Children   7.55
# 3           PG-13 - Teens 13 or older   8.21
# 4           PG-13 - Teens 13 or older   8.67
# ...                               ...    ...
# 14473                    G - All Ages   5.50
# 14474                    G - All Ages   4.60
# 14475  R - 17+ (violence & profanity)   0.00
# 14476                    G - All Ages   6.00
# 14477       PG-13 - Teens 13 or older   5.15
#
#                                                  related  \
# 0      {'Adaptation': [{'mal_id': 17207, 'type': 'man...
# 1      {'Adaptation': [{'mal_id': 759, 'type': 'manga...
# 2      {'Adaptation': [{'mal_id': 101, 'type': 'manga...
# 3      {'Adaptation': [{'mal_id': 1581, 'type': 'mang...
# 4      {'Adaptation': [{'mal_id': 9711, 'type': 'mang...
# ...                                                  ...
# 14473  {'Other': [{'mal_id': 26087, 'type': 'anime', ...
# 14474                                                 []
# 14475  {'Prequel': [{'mal_id': 36816, 'type': 'anime'...
# 14476                                                 []
# 14477  {'Other': [{'mal_id': 5507, 'type': 'anime', '...
#
#                                                 producer          licensor  \
# 0      Aniplex, Square Enix, Mainichi Broadcasting Sy...  Sentai Filmworks
# 1                      TV Tokyo, AIC, Square Enix, Sotsu        Funimation
# 2                                        TV Tokyo, Sotsu               NaN
# 3                     Memory-Tech, GANSIS, Marvelous AQL         ADV Films
# 4                                          NHK, Shueisha               NaN
# ...                                                  ...               ...
# 14473                                                NaN               NaN
# 14474                                       Studio Lotus               NaN
# 14475                                                NaN               NaN
# 14476                                                NaN               NaN
# 14477                                                NaN               NaN
#
#                  studio                                     genre  \
# 0      David Production    Comedy, Supernatural, Romance, Shounen
# 1                 Gonzo  Comedy, Parody, Romance, School, Shounen
# 2             Satelight             Comedy, Magic, School, Shoujo
# 3        Hal Film Maker    Comedy, Drama, Magic, Romance, Fantasy
# 4             J.C.Staff           Comedy, Drama, Romance, Shounen
# ...                 ...                                       ...
# 14473               NaN                                      Kids
# 14474               NaN                                    Comedy
# 14475               NaN        Action, Sci-Fi, Adventure, Fantasy
# 14476               NaN                             Fantasy, Kids
# 14477      A-1 Pictures                                    Comedy
#
#                                            opening_theme  \
# 0                                  ['"Nirvana" by MUCC']
# 1                     ['"Romantic summer" by SUN&LUNAR']
# 2      ['#1: "Minna no Tamago (みんなのたまご)" by Shugo Cha...
# 3                 ['"Morning Grace" by Ritsuko Okazaki']
# 4      ['#1: "Moshimo no Hanashi (もしもの話)" by nano.RIP...
# ...                                                  ...
# 14473                                                 []
# 14474                                                 []
# 14475                                                 []
# 14476                                                 []
# 14477                                                 []
#
#                                             ending_theme
# 0      ['#1: "Nirvana" by MUCC (eps 1, 11-12)', '#2: ...
# 1      ['#1: "Ashita e no Hikari (明日への光)" by Asuka Hi...
# 2      ['#1: "Rottara Rottara (ロッタラ ロッタラ)" by Buono! ...
# 3      ['"Watashi No Ai Wa Chiisaikeredo" by Ritsuko ...
# 4      ['#1: "Pride on Everyday" by Sphere (eps 1-13)...
# ...                                                  ...
# 14473                                                 []
# 14474                                                 []
# 14475                                                 []
# 14476                                                 []
# 14477                                                 []
#
# [14478 rows x 16 columns]

# %% [markdown]
# ### Looking for outliers by ValueCounts on each feature

# %% [markdown]
# Checked also 'type', 'source', 'rating' - these seem fine
# 'genre' we should maybe encode

# %%
print(df_copy['episodes'].value_counts()) # A ton of outliers - maybe we can use some range encoding
# Out:
# episodes
# 1      6857
# 2      1187
# 12     1034
# 13      637
# 3       558
#        ...
# 161       1
# 150       1
# 220       1
# 167       1
# 132       1
# Name: count, Length: 196, dtype: int64

# %%
print(df_copy['duration'].value_counts()) # A ton of outliers, since theres a lot of movies - maybe we can use some range encoding
# Out:
# duration
# 24 min. per ep.          1513
# 25 min. per ep.           808
# 23 min. per ep.           797
# 30 min. per ep.           749
# 2 min.                    476
#                          ...
# 46 sec. per ep.             1
# 1 hr. 17 min. per ep.       1
# 49 sec. per ep.             1
# 2 hr. 19 min.               1
# 12 sec. per ep.             1
# Name: count, Length: 301, dtype: int64

# %%
print(df_copy['score'].value_counts()) # Something needs to be done here
print(df_copy['score'].sum() / df_copy['score'].count()) # Average score is 6.14
# Out:
# score
# 0.00    354
# 6.00    120
# 5.00    100
# 6.50     90
# 6.33     87
#        ...
# 3.17      1
# 9.14      1
# 9.20      1
# 3.12      1
# 1.33      1
# Name: count, Length: 630, dtype: int64
# 6.142481696366902

# %%
print(df_copy['related'][0]) # could be interesting if we wanted to look at the related media has any influence on score
# Out:
# {'Adaptation': [{'mal_id': 17207, 'type': 'manga', 'url': 'https://myanimelist.net/manga/17207/Inu_x_Boku_SS', 'title': 'Inu x Boku SS'}], 'Sequel': [{'mal_id': 13403, 'type': 'anime', 'url': 'https://myanimelist.net/anime/13403/Inu_x_Boku_SS_Special', 'title': 'Inu x Boku SS Special'}]}

# %%
print(df_copy['opening_theme'])

def check_value(value):
    if len(value) <= 2: # 2 charcters is empty array huh
        return True
    else:
        return False

count = df_copy['opening_theme'].apply(check_value).sum()
print(count)
# Out:
# 0                                    ['"Nirvana" by MUCC']
# 1                       ['"Romantic summer" by SUN&LUNAR']
# 2        ['#1: "Minna no Tamago (みんなのたまご)" by Shugo Cha...
# 3                   ['"Morning Grace" by Ritsuko Okazaki']
# 4        ['#1: "Moshimo no Hanashi (もしもの話)" by nano.RIP...
#                                ...
# 14473                                                   []
# 14474                                                   []
# 14475                                                   []
# 14476                                                   []
# 14477                                                   []
# Name: opening_theme, Length: 14478, dtype: object
# 9784
